# %% [markdown]
# # Ejercicio1 - Utilizar operadores aritméticos

# %%
distanciaTierra = 149597870 
distanciaJupites = 778547200

# %% [markdown]
# Calcular la distancia entre planetas

# %%
distancia = distanciaJupites - distanciaTierra
milla = 0.621
distanciaEnMillas = distancia * milla
print(distanciaEnMillas)
# Out:
# 390577533.93

# %% [markdown]
# # Ejercicio 2: convierte cadenas en números y usa valores absolutos

# %% [markdown]
# Almacenar las entradas del usuario
# Convierte las cadenas de ambos planetas a números enteros
# Realizar el cálculo y determinar el valor absoluto

# %%
primerPlaneta = input('Kilómetros de distancia entre el sol y el primer planeta')
segundoPlaneta = input('Kilómetros de distancia entre el sol y el segundo planeta')
distanciaPrimerPlaneta = int(primerPlaneta)
distanciaSegundoPlaneta = int(segundoPlaneta)

distancia =  distanciaPrimerPlaneta - distanciaSegundoPlaneta
distanciaAbsoluta = abs(distancia)
milla = 0.621
distanciaEnMillas = distanciaAbsoluta * milla
print(distanciaEnMillas)
# Out:
# 31236300.0
